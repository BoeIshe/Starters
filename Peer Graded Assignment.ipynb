# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# # Bothwell
# My desired occupation is to be a data scientist for a big data consultancy firm

# %% [markdown]
#  𝐼𝓂 𝒾𝓃𝓉𝑒𝓇𝑒𝓈𝓉𝑒𝒹 𝒾𝓃 𝒟𝒶𝓉𝒶 𝒮𝒸𝒾𝑒𝓃𝒸𝑒 𝒷𝑒𝒸𝒶𝓊𝓈𝑒 𝒾𝓂 𝒸𝓊𝓇𝒾𝑜𝓊𝓈 𝒶𝒷𝑜𝓊𝓉 𝒹𝒶𝓉𝒶 𝒶𝓃𝒹 𝒾𝓉𝓈 𝒾𝓃𝓉𝑒𝓇𝓇𝓅𝓇𝑒𝓉𝒶𝓉𝒾𝑜𝓃. 𝒯𝒽𝑒𝓇𝑒 𝒾𝓈 𝓈𝑜 𝓂𝓊𝒸𝒽 𝒾𝓃𝒻𝑜𝓇𝓂𝒶𝓉𝒾𝑜𝓃 𝒽𝒾𝒹𝒹𝑒𝓃 𝒾𝓃 𝒹𝒶𝓉𝒶 𝓉𝒽𝒶𝓉 𝓌𝑒 𝒽𝒶𝓋𝑒 𝒶𝓋𝒶𝒾𝓁𝒶𝒷𝓁𝑒 𝒾𝓃 𝑜𝓊𝓇 𝒹𝒶𝓎 𝓉𝑜 𝒹𝒶𝓎 𝓁𝒾𝓋𝑒𝓈 𝒶𝓃𝒹 𝓊𝓃𝒸𝑜𝓋𝑒𝓇𝒾𝓃𝑔 𝒶𝓁𝓁 𝓉𝒽𝒶𝓉 𝒷𝓇𝒾𝓃𝑔𝓈 𝓂𝑒 𝓈𝑜 𝓂𝓊𝒸𝒽 𝒽𝒶𝓅𝓅𝒾𝓃𝑒𝓈𝓈

# %% [markdown]
# The following code executes the code to output the result

# %%
print("Welcome World")
# Out:
# Welcome World

# %% [markdown]
# 1)Open the Try IBM Security Verify page https://www.ibm.com/account/reg/us-en/signup?formid=urx-30041 in a browser.
#
# -If you already have an IBM account, click Log in.
#
# -Otherwise, fill in your account information and click Start Your Free Edition and respond to the verification email.
#
# -In both cases, you receive a verification email. Your IBM account is added to the IBM Cloud Identity admin group for the hostname you configure.
#
# 2)On the IBM Cloud Identity Connect Registration page, enter a host name. The hostname you specify is then used in a URL of the form https://hostname.ice.ibmcloud.com.
#
# 3)Click Start Trial.
#
# 4)The https://hostname.ice.ibmcloud.com/ui/admin page is displayed.
